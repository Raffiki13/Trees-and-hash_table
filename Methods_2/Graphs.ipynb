# %%
import matplotlib.pyplot as plt

X = [x for x in range(10)]
bst = [4.399917088449001e-06, 4.600035026669502e-06, 2.299901098012924e-06, 4.800036549568176e-06, 3.0999071896076202e-06, 2.800021320581436e-06, 4.399917088449001e-06, 3.1999079510569572e-06, 3.100023604929447e-06, 2.100015990436077e-06]
bst_2 = [7.999944500625134e-06, 3.600027412176132e-06, 8.09994526207447e-06, 4.300032742321491e-06, 4.00003045797348e-06, 6.100046448409557e-06, 5.400041118264198e-06, 5.200039595365524e-06, 8.300063200294971e-06, 4.299916326999664e-06]
bst_3 = [2.5099958293139935e-05, 1.6600009985268116e-05, 1.3500102795660496e-05, 1.6000005416572094e-05, 1.3399985618889332e-05, 8.79995059221983e-06, 1.309998333454132e-05, 1.479999627918005e-05, 9.999959729611874e-06, 1.0100076906383038e-05]
plt.semilogy(X, bst, label='200')
plt.semilogy(X, bst_2, label='1000')
plt.semilogy(X, bst_3, label='150000')
plt.title('BST time searching')
plt.grid()
plt.legend()
plt.show()

# %%
X = [x for x in range(10)]
rbt = [7.200054824352264e-06, 8.299946784973145e-06, 4.800036549568176e-06, 6.100046448409557e-06, 2.900022082030773e-06, 5.400041118264198e-06, 3.100023604929447e-06, 3.8000289350748062e-06, 3.900029696524143e-06, 4.900037311017513e-06]
rbt_2 = [2.929999027401209e-05, 1.7300015315413475e-05, 1.8300022929906845e-05, 1.7799902707338333e-05, 1.5099998563528061e-05, 1.1199968867003918e-05, 1.5700003132224083e-05, 6.3999323174357414e-06, 1.9200029782950878e-05, 1.4599994756281376e-05]
rbt_3 = [9.490002412348986e-05, 3.6800047382712364e-05, 1.650000922381878e-05, 4.20999713242054e-05, 3.470003139227629e-05, 1.7700018361210823e-05, 2.6699970476329327e-05, 3.930006641894579e-05, 4.160008393228054e-05, 2.4900073185563087e-05]
plt.semilogy(X, rbt, label='200')
plt.semilogy(X, rbt_2, label='1000')
plt.semilogy(X, rbt_3, label='150000')
plt.title('RBT time searching')
plt.grid()
plt.legend()
plt.show()

# %%
X = [x for x in range(10)]
ht = [1.7900019884109497e-05, 1.479999627918005e-05, 8.899951353669167e-06, 8.699949830770493e-06, 1.6300007700920105e-05, 1.1399970389902592e-05, 1.1199968867003918e-05, 1.0999967344105244e-05, 1.1100084520876408e-05, 1.2600095942616463e-05]
ht_2 = [1.370010431855917e-05, 1.2999982573091984e-05, 1.7400016076862812e-05, 7.999944500625134e-06, 1.1999974958598614e-05, 2.1300045773386955e-05, 1.170008908957243e-05, 7.00005330145359e-06, 5.999929271638393e-06, 9.400071576237679e-06]
ht_3 = [1.3299984857439995e-05, 1.0200077667832375e-05, 2.4700071662664413e-05, 1.3200100511312485e-05, 1.27000967040658e-05, 1.7300015315413475e-05, 1.2899981811642647e-05, 1.5099998563528061e-05, 2.0799925550818443e-05, 4.640000406652689e-05]
plt.semilogy(X, ht, label='200')
plt.semilogy(X, ht_2, label='1000')
plt.semilogy(X, ht_3, label='150000')
plt.title('HT time searching')
plt.grid()
plt.legend()
plt.show()

# %%
collision_tmp = [60022, 64996, 68999]
plt.plot([200, 10000, 150000], collision_tmp, label='Collision')
plt.title('Collision number')
plt.legend()
plt.grid()
plt.show()

# %%
mm = [1.800013706088066e-06, 1.200009137392044e-06, 6.00004568696022e-07, 5.00003807246685e-07, 5.00003807246685e-07, 4.00003045797348e-07, 3.00002284348011e-07, 3.00002284348011e-07, 4.00003045797348e-07, 3.00002284348011e-07]
mm_2 = [1.00000761449337e-06, 5.00003807246685e-07, 3.00002284348011e-07, 2.00001522898674e-07, 3.00002284348011e-07, 2.00001522898674e-07, 4.00003045797348e-07, 3.00002284348011e-07, 3.00002284348011e-07, 2.998858690261841e-07]
mm_3 = [1.800013706088066e-06, 7.00005330145359e-07, 8.00006091594696e-07, 6.00004568696022e-07, 4.00003045797348e-07, 3.00002284348011e-07, 5.00003807246685e-07, 6.998889148235321e-07, 6.00004568696022e-07, 5.00003807246685e-07]
plt.semilogy(X, mm, label='200')
plt.semilogy(X, mm_2, label='1000')
plt.semilogy(X, mm_3, label='150000')
plt.title('MultiMap time searching')
plt.grid()
plt.legend()
plt.show()

# %%
bst_avg = [(bst[x] + bst_2[x] + bst_3[x]) / 3 for x in range(len(bst))]
rbt_avg = [(rbt[x] + rbt_2[x] + rbt_3[x]) / 3 for x in range(len(rbt))]
ht_avg = [(ht[x] + ht_2[x] + ht_3[x]) / 3 for x in range(len(ht))]
mm_avg = [(mm[x] + mm_2[x] + mm_3[x]) / 3 for x in range(len(mm))]
X = [x for x in range(10)]
plt.semilogy(X, mm_avg, label='multimap')
plt.semilogy(X, ht_avg, label='hash table')
plt.semilogy(X, rbt_avg, label='rb tree')
plt.semilogy(X, bst_avg, label='bin tree')
plt.title('All ways')
plt.legend()
plt.grid()
plt.show()
